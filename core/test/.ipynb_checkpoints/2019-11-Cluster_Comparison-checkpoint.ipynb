# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io
import scipy
import sklearn.neighbors
import umap
import seaborn as sns
import hdbscan

# %% [markdown]
# Load clustering results

# %%
# Umap results for precomputed metric
umap_precomputed_df = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/UMAP_precomputed_df.pkl')
umap_precomputed = np.load('/Users/jenniferthem/Masterthesis/core/data/UMAP_precomputed.npy')
# Umap results for precomputed metric with ROI labels
umap_roi_precomputed = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/UMAP_precomputed_labeled.pkl')
# Umap results for euclidean metric with ROI labels
umap_roi_euclidean = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/UMAP_euclidean_labeled.pkl')
# Umap results for euclidean metric
umap_euclidean = np.load('/Users/jenniferthem/Masterthesis/core/data/UMAP_euclidean.npy')

# HDBScan labels for precomputed metric
# array
hdbscan_labels_precomputed = np.load('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labels.npy')
# dataframe
hdbscan_labels_precomputed_df = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labels_precomputed_df.pkl')
# HDBScan labels for euclidean metric
hdbscan_labels_euclidean = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labels_euclidean.pkl')
hdbscan_labels_euclidean = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labels_euclidean.pkl')
# UMAP precomputed metric + HDBScan labels
hdbscan_labeled_data_precomputed = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labeled_data_precomputed.pkl')
# UMAP euclidean metric + HDBScan labels
hdbscan_labeled_data_euclidean = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labeled_data_euclidean.pkl')

# ROI labels
roi_labels = pd.read_pickle('/Users/jenniferthem/Masterthesis/core/data/roi_labels.pkl')
# HDBScan labels in array format from precomputed
hdbscan_labels = np.load('/Users/jenniferthem/Masterthesis/core/data/HDBScan_labels.npy')

# %% [markdown]
# Creating seaborn custom made color palette

# %%
colors = ['#ED1D0C','#808000', '#FA8072', '#7DDCAC', '#097E02', '#7988DF', '#38E1F5', '#1C0BEA', '#39374D', '#EC7BD9', '#560449', '#D192B8', '#F57A64', '#921701', '#A877EE', '#E2F337', '#BD11A1', '#89AB94']

# %%
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))

# %% [markdown]
# ## UMAP embedding with ROI labels

# %%
# %matplotlib notebook
sp = sns.scatterplot(x="x", y="y", hue='label', data=umap_roi_precomputed, s=5)
plt.legend(bbox_to_anchor=(0.9, 1), loc=2, borderaxespad=0.)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
facet = sns.lmplot(data=umap_roi_precomputed, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True, scatter_kws={"s": 1})
# Out:
# <img src="data:image/png;base64,..." width="612">

# %%
#plot data with seaborn (don't add a legend yet)
facet = sns.lmplot(data=umap_roi_precomputed, x='x', y='y', hue='label', 
                   fit_reg=False, legend=False)

#add a legend
leg = facet.ax.legend(bbox_to_anchor=[1, 0.75],
                         title="label", fancybox=True)
#change colors of labels
for i, text in enumerate(leg.get_texts()):
    plt.setp(text, color = customPalette[i])

# %%
# %matplotlib notebook
sp = sns.scatterplot(x="x", y="y", hue='label', data=umap_roi_euclidean, s=5)
plt.legend(bbox_to_anchor=(0.9, 1), loc=2, borderaxespad=0.)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Clustering HDBScan

# %%
# %matplotlib notebook
# what tf is going on?
sp = sns.scatterplot(x="x", y="y", hue='label', data=hdbscan_labeled_data_precomputed[clustered], s=5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# -1 is noise
facet = sns.lmplot(data=hdbscan_labeled_data_precomputed, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True, scatter_kws={"s": 1}, palette = 'Paired')
# Out:
# <img src="data:image/png;base64,..." width="1127">

# %% [markdown]
# Drawing only clustered voxels

# %%
# voxels that are clustered by HDBScan - throwing out noise
clustered = (hdbscan_labels >= 0)
#clustered.columns=['clustered']

# %%
clu_roi_data = pd.concat([umap_roi_precomputed, clustered], axis=1, sort=False)
clu_roi_data.to_pickle('/Users/jenniferthem/Masterthesis/core/data/clustered_roi_data.pkl')

# %%
# iterate through df
# if last column == false -> delete this row 
# output: df with only the clustered voxels
#for row in clu_roi_data.rows:
 #   if clu_roi_data.iloc[row, 4]==False:
  #      print("hallo")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-06ae02442261> in <module>
#       2 # if last column == false -> delete this row
#       3 # output: df with only the clustered voxels
# ----> 4 for row in clu_roi_data.rows:
#       5     if clu_roi_data.iloc[row, 4]==False:
#       6         print("hallo")
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
umap_roi_precomputed_arr = umap_precomputed.to_numpy()
clustered_arr = clustered.to_numpy()

# %%
umap_roi_precomputed_arr
# Out:
# array([[-2.4775577 ,  0.17769322],
#        [-1.7575141 ,  0.41984466],
#        [-0.5437139 , -1.1101503 ],
#        ...,
#        [-1.1942105 ,  1.7000955 ],
#        [-1.1738976 ,  1.6881825 ],
#        [-1.110674  ,  1.4063737 ]], dtype=float32)

# %%
clustered
# Out:
# array([ True, False, False, ...,  True,  True, False])

# %%
plt.scatter(umap_roi_precomputed_arr[~clustered, 0],
            umap_roi_precomputed_arr[~clustered, 1],
            c=(0.5, 0.5, 0.5),
            s=0.1,
            alpha=0.5)
plt.scatter(umap_roi_precomputed_arr[clustered, 0],
            umap_roi_precomputed_arr[clustered, 1],
            c=roi_labels[clustered],
            s=0.1,
            cmap='Spectral');
# Out:
# <div id='5f92750b-923c-4a61-b049-e9e256c88d3c'></div>
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4284             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4285                 colors = mcolors.to_rgba_array(c)
#    4286                 n_elem = colors.shape[0]
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# ...
