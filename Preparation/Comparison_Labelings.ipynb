# %%
import numpy as np
import pandas as pd

# %%
# OLD & with wrong indeces due to load_nii
mask_label_pfc_old= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/Mask_ind_pfc.csv', engine='c', header = None)
mask_label_str_old= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/Mask_ind_str.csv', engine='c', header = None)
# pfc and striatum labels
label_pfc_old= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/PFC_ROIs.csv', engine='c', header = None)
label_str_old= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/Striatum_ROIs.csv', engine='c', header = None)

# %%
mask_label_pfc_new.iloc[7044]
# Out:
# 0    385619
# Name: 7044, dtype: int64

# %%
label_pfc_new.iloc[7044]
# Out:
# 0    FP2
# Name: 7044, dtype: object

# %%
label_pfc_old.iloc[7044]
# Out:
# 0    OFC5
# Name: 7044, dtype: object

# %%
#NEW
mask_label_pfc_new= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Labeling/Mask_ind_pfc_new.csv', engine='c', header = None)
mask_label_str_new= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Labeling/Mask_ind_str_new.csv', engine='c', header = None)
# pfc and striatum labels
label_pfc_new= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Labeling/PFC_ROIs.csv', engine='c', header = None)
label_str_new= pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Labeling/Striatum_ROIs.csv', engine='c', header = None)

# %%
pd.concat([mask_label_pfc_new, mask_label_pfc_old], axis=1)
# Out:
#            0       0
# 0     205886  205889
# 1     205887  205890
# 2     205978  205980
# 3     206069  206071
# 4     206160  206162
# ...      ...     ...
# 8959  531666  531671
# 8960  531756  531761
# 8961  531757  531762
# 8962  531847  531852
# 8963  531848  531853
#
# [8964 rows x 2 columns]

# %%
pd.concat([label_pfc_new, label_pfc_old], axis=1)
# Out:
#          0     0
# 0     OFC1  OFC1
# 1     OFC1  OFC1
# 2     OFC1  OFC1
# 3     OFC1  OFC1
# 4     OFC1  OFC1
# ...    ...   ...
# 8959    33    33
# 8960    33    33
# 8961    33    33
# 8962    33    33
# 8963    33    33
#
# [8964 rows x 2 columns]

# %%
label_pfc_new.equals(label_pfc_old)
# Out:
# False

# %%
new=label_pfc_new.values.tolist()
old=label_pfc_old.values.tolist()

# %%
sum=0
for i in range (len(new)):
    if new[i]!=old[i]:
        sum+=1
        print("Exception: ", i)
        
print("Sum: ", sum)
# Out:
# Exception:  14
# Exception:  18
# Exception:  67
# Exception:  68
# Exception:  70
# Exception:  76
# Exception:  77
# Exception:  90
# Exception:  91
# Exception:  105
# Exception:  107
# Exception:  120
# Exception:  125
# Exception:  133
# Exception:  138
# Exception:  144
# Exception:  145
# Exception:  151
# Exception:  154
# Exception:  168
# Exception:  171
# Exception:  184
# Exception:  201
# Exception:  214
# Exception:  266
# Exception:  275
# Exception:  276
# Exception:  281
# Exception:  290
# Exception:  295
# Exception:  380
# Exception:  394
# Exception:  407
# Exception:  420
# Exception:  430
# Exception:  443
# Exception:  475
# Exception:  476
# Exception:  482
# Exception:  483
# Exception:  493
# Exception:  504
# Exception:  528
# Exception:  540
# Exception:  561
# Exception:  573
# Exception:  622
# Exception:  631
# Exception:  634
# Exception:  643
# Exception:  646
# Exception:  655
# Exception:  683
# Exception:  693
# Exception:  761
# Exception:  774
# ...

# %%
new[14]
# Out:
# ['OFC2']

# %%
old[14]
# Out:
# ['OFC1']

# %%
new_s=label_str_new.values.tolist()
old_s=label_str_old.values.tolist()

# %%
sum=0
for i in range (len(new_s)):
    if new_s[i]!=old_s[i]:
        sum+=1
        print("Exception: ", i)
print("Sum: ", sum)
# Out:
# Exception:  0
# Exception:  1
# Exception:  2
# Exception:  5
# Exception:  6
# Exception:  7
# Exception:  11
# Exception:  16
# Exception:  20
# Exception:  21
# Exception:  22
# Exception:  23
# Exception:  24
# Exception:  25
# Exception:  26
# Exception:  27
# Exception:  50
# Exception:  57
# Exception:  131
# Exception:  132
# Exception:  196
# Exception:  203
# Exception:  280
# Exception:  287
# Exception:  406
# Exception:  411
# Exception:  449
# Exception:  457
# Exception:  492
# Exception:  493
# Exception:  500
# Exception:  501
# Exception:  528
# Exception:  535
# Exception:  540
# Exception:  545
# Exception:  648
# Exception:  651
# Exception:  666
# Exception:  671
# Exception:  686
# Exception:  687
# Exception:  691
# Exception:  692
# Exception:  706
# Exception:  707
# Exception:  713
# Exception:  714
# Exception:  728
# Exception:  734
# Exception:  746
# Exception:  748
# Exception:  754
# Exception:  756
# Exception:  764
# Exception:  774
# ...

# %%
new_s
# Out:
# [['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
# ...

# %%
old_s
# Out:
# [['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['NAcc'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
#  ['Putamen'],
# ...
