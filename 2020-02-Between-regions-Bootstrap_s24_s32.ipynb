# %% [markdown]
# # Bootstrap region s24 and s32 to all other ROI centroids

# %% [markdown]
# This script bootstraps the following differences:
# * Ketamine-Baseline
# * Placebo-Baseline
# * (Ketamine-Baseline) - (Placebo-Baseline)
#
# for regions s24 and s32 that were previously chosen due to the results of the within-ROI analysis.
# Then the mean of these bootstrap results is taken and depicted in heatmap to cpmare the conditions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io
import scipy
import seaborn as sns
import os
import pickle
import copy
import bootstrapped.bootstrap as bs
import bootstrapped.compare_functions as bs_compare
import bootstrapped.stats_functions as bs_stats
import scipy.stats as st

# %% [markdown]
# Load dataframes containing the distance values from each voxel to all ROI centroids

# %%
p = np.load('/Users/jenniferthem/Masterthesis_Data/January2020/voxel_all_centroids_placebo', allow_pickle=True)
b_p = np.load('/Users/jenniferthem/Masterthesis_Data/January2020/voxel_all_centroids_baseline_p', allow_pickle=True)
k = np.load('/Users/jenniferthem/Masterthesis_Data/January2020/voxel_all_centroids_ketamine', allow_pickle=True)
b_k = np.load('/Users/jenniferthem/Masterthesis_Data/January2020/voxel_all_centroids_baseline_ket', allow_pickle=True)
roi_labels = np.load('/Users/jenniferthem/Masterthesis_Data/roi_labels.npy', allow_pickle=True)

# %%
p
# Out:
#            OFC1      OFC2      OFC3      OFC4      OFC5      OFC6      OFC7  \
# 0      0.226733  0.422894  1.335219  3.148752  2.788927  4.410674  3.748523
# 1      0.528746  0.516267  1.025515  2.843058  2.484603  4.096969  3.428747
# 2      0.182466  0.659102  1.453361  3.124055  2.763164  4.401328  3.760737
# 3      0.454224  0.563894  1.115213  2.870370  2.510544  4.133254  3.474313
# 4      0.529827  0.909140  2.056627  3.812401  3.451538  5.090403  4.446981
# ...         ...       ...       ...       ...       ...       ...       ...
# 11878  8.106480  7.649629  6.603138  6.290796  6.438685  5.681016  5.553036
# 11879  8.096053  7.638746  6.593255  6.284916  6.432130  5.677748  5.547953
# 11880  8.083270  7.625710  6.580792  6.275234  6.421938  5.670165  5.538893
# 11881  8.084783  7.627735  6.581721  6.272495  6.419757  5.665441  5.535518
# 11882  8.078866  7.621840  6.575795  6.266892  6.414061  5.660309  5.530041
#
#             s32        FP2        25       s24        33        p32  \
# 0      2.748099   5.059959  0.679296  2.755289  2.890687   6.181243
# 1      3.055861   5.381871  0.723912  3.058456  3.131667   6.498226
# 2      2.795300   5.052827  0.915925  2.812625  3.028825   6.194837
# 3      3.026470   5.333057  0.791139  3.033285  3.144631   6.458054
# 4      2.129434   4.363946  1.102069  2.156257  2.509102   5.507191
# ...         ...        ...       ...       ...       ...        ...
# 11878  9.869950  12.269585  7.498972  9.799138  9.078177  13.086680
# 11879  9.857620  12.256955  7.487832  9.786733  9.065178  13.073574
# 11880  9.843915  12.243145  7.474662  9.773000  9.051268  13.059641
# 11881  9.847746  12.247403  7.476984  9.776936  9.056084  13.064628
# 11882  9.842041  12.241769  7.471109  9.771248  9.050562  13.059144
#
#            p24ab       p24c    Putamen      NAcc   Caudate
# 0       5.461668   6.185415   9.863185  8.398568  8.339620
# 1       5.764049   6.494627   9.698022  8.175587  8.085256
# 2       5.513580   6.221405  10.085056  8.596735  8.517674
# 3       5.739689   6.463776   9.806347  8.283055  8.189319
# 4       4.844483   5.541670  10.336788  8.981193  8.975653
# ...          ...        ...        ...       ...       ...
# 11878  12.014162  12.833250   4.696659  2.204799  1.095627
# 11879  12.000829  12.819908   4.688725  2.195998  1.090209
# 11880  11.986859  12.805937   4.685505  2.191822  1.089854
# 11881  11.992230  12.811324   4.695954  2.202490  1.099344
# 11882  11.986839  12.805936   4.697377  2.203512  1.101932
#
# [11883 rows x 18 columns]

# %%
np.amax(p)
# Out:
# OFC1       10.742996
# OFC2       10.159299
# OFC3        9.692215
# OFC4       11.255213
# OFC5       10.894404
# OFC6       12.532006
# OFC7       11.872709
# s32        11.319818
# FP2        13.336679
# 25          9.918939
# s24        11.212269
# 33         10.195646
# p32        13.763094
# p24ab      12.583925
# p24c       13.373869
# Putamen    14.843263
# NAcc       14.541402
# Caudate    15.005191
# dtype: float64

# %%
# prepare roi labels 
roi_list = []
for i in range(len(roi_labels)):
    roi_list.append(copy.deepcopy(roi_labels[i][0]))

# %%
# label the voxels
p['label']= roi_list
b_p['label']= roi_list
k['label']= roi_list
b_k['label']= roi_list

# %%
# list of the ROIs
rois = ['OFC1','OFC2','OFC3','OFC4','OFC5','OFC6','OFC7','s32','FP2','25','s24','33','p32','p24ab','p24c','Putamen','NAcc','Caudate']

# %% [markdown]
# Extracting of only s24 and s32 voxels + dropping the label columns

# %%
s24_b_k = b_k[b_k['label']=='s24'].drop(['label'], axis=1)
s24_k = k[k['label']=='s24'].drop(['label'], axis=1)
s24_p = p[p['label']=='s24'].drop(['label'], axis=1)
s24_b_p = b_p[b_p['label']=='s24'].drop(['label'], axis=1)

# %%
s32_b_k = b_k[b_k['label']=='s32'].drop(['label'], axis=1)
s32_k = k[k['label']=='s32'].drop(['label'], axis=1)
s32_p = p[p['label']=='s32'].drop(['label'], axis=1)
s32_b_p = b_p[b_p['label']=='s32'].drop(['label'], axis=1)

# %% [markdown]
# Calculating the differences as preparation for bootstrap

# %%
# ketamine - baseline
s24_k_sub_b = s24_k - s24_b_k
# placebo - baseline
s24_p_sub_b = s24_p - s24_b_p
# (ketamine-b) - (placebo-b)
s24_k_p = s24_k_sub_b - s24_p_sub_b

# %%
# ketamine - baseline
s32_k_sub_b = s32_k - s32_b_k
# placebo - baseline
s32_p_sub_b = s32_p - s32_b_p
# (ketamine-b) - (placebo-b)
s32_k_p = s32_k_sub_b - s32_p_sub_b

# %%
np.asarray(s24_k_sub_b['OFC1'])
# Out:
# array([-0.28367793, -0.21739685, -0.42245208, -0.59763346, -0.35400253,
#        -0.04073392,  0.1621548 , -0.35027662, -0.61478763, -0.20470952,
#        -0.04323078, -0.11649534,  0.0274907 , -0.09531477, -2.50578913,
#         0.01650524, -0.32726157, -0.06572374, -2.06432901,  0.02379166,
#        -0.31749548, -0.13972897, -0.33449304, -0.06979775, -0.47263738,
#        -0.25079989, -0.11202746, -0.3850429 ,  0.04159964,  0.05896364,
#         2.73916845, -0.52675495, -1.20749812, -0.8174413 , -0.21951608,
#         5.62410156,  2.01238352,  3.38987405, -1.42366121,  4.74427887,
#        -0.5315764 ,  2.11762811,  2.33062611,  2.85353795,  3.63987703,
#         2.7866179 , -0.58690526, -0.74239207, -0.08510712, -0.12199154,
#         0.56539402, -2.06426889,  5.76441222, -0.24325278,  0.26750962,
#         5.70890276,  2.97295205,  4.3555038 ,  4.97582069,  4.67389469,
#         2.55211604,  2.9489086 ,  3.43017259,  2.85146538,  3.79008389,
#         4.5307589 ,  0.95830157, -6.1671968 ,  2.59517681,  2.20220685,
#         1.82726036,  2.45925683,  3.10568365,  3.66631911,  1.18565265,
#         2.00541938,  2.68117955,  3.07878539,  2.96343407, -3.26641842,
#        -0.59552575,  2.51839241,  2.81356904,  2.73084072, -4.0998088 ,
#         1.15410693,  2.78197668,  1.87946913, -1.16925942, -0.65616229,
#        -0.20805131, -0.34939347,  0.09282981, -2.88140953, -0.93153458,
#         5.37234609, -0.54549726, -0.65411881, -0.18460156, -0.38177802,
#         0.08405767, -2.8751458 ,  4.72487909,  5.25086361, -0.62412738,
#        -0.5020632 , -0.69681529, -3.138664  ,  3.15042878,  2.92161909,
#         2.12353921,  1.76976255,  2.04750211,  2.47294988,  2.78391185,
#         2.0426525 ,  1.15020866,  5.65084125,  1.84780094,  1.67317298,
#         2.01771167,  2.7184258 ,  2.21694071,  1.81696654,  1.18242154,
#         1.52261389,  2.05464563,  1.35509428,  2.52264247,  2.3132347 ,
#         2.22445054,  2.52113847,  1.81797133,  2.0279773 ,  2.13253015,
#         2.25880973,  2.38244192,  1.9957683 ,  2.63779906,  2.21059248,
#         2.27926259,  2.00363371,  2.31099692,  2.23125903,  2.15180687,
#         2.60271124, -0.60997001, -0.50212286,  5.26687679, -0.68308722,
#        -0.71089102, -0.40007927, -0.62432164, -0.66881032, -0.28511618,
#        -4.77596542, -0.65210119, -0.47330678, -0.20551216, -0.65290294,
#        -3.71152239,  0.83289138,  1.91297153, -4.53559822, -0.3858768 ,
#        -6.76097846,  1.67685296,  2.57733922,  1.99150281,  3.31697807,
#         2.11319078,  2.33512784,  7.09123284,  1.63804999,  2.13791384,
#         2.56966102,  2.56581301,  2.2943074 ,  2.40300633,  2.0568575 ,
#         1.79073961,  2.70512077,  2.49052933,  2.24592459,  2.1319304 ,
#         1.95846696,  2.05446967,  1.36549364,  1.19592801,  2.35388991,
#         2.33177636,  1.95242753,  2.03770184,  2.25547782,  2.17806561,
#         1.33139825,  2.1601949 ,  2.14158343,  2.02591744,  2.06352436,
#         1.86094213,  2.01061014,  1.80030673,  1.59471484,  1.82997927,
#         2.20108233,  2.20694176,  2.18027833,  1.62567477,  1.89151984,
#        -0.15281018, -0.34981902,  0.05112725,  0.25291916, -0.62580461,
#        -0.10401252, -0.47208521, -0.0351895 , -4.61166322, -0.62749893,
#        -0.51601349,  0.31195228,  1.22967934,  1.65274374, -1.46633855,
#         1.31171959,  2.78423413,  2.47927431,  2.55153789,  2.82573908,
#         2.98685099,  1.58015915,  2.58299021,  2.56294021,  1.93791055,
#         3.90646186,  2.07019529,  1.41068326,  2.74475917,  2.51756249,
#         2.01436711,  1.79785581,  2.01830179,  1.43141904,  1.01770656,
#         2.25410423,  2.25574084,  2.12636693,  1.77666901,  2.25940208,
#         1.58868013,  1.09489239,  2.16532285,  2.04634693,  1.7851703 ,
#         1.86257732,  1.84292257,  1.59484946,  2.06334649,  2.16482418,
#         2.21470044,  1.6285858 ,  1.7915384 ,  2.01077232,  2.09185638,
#         2.21008295,  0.07210131, -0.06749944,  0.33319365, -0.04005753,
#        -0.05845108, -0.06398824, -0.66442315,  0.28933139,  0.57687371,
#        -0.48955914,  0.00987743,  5.2625118 ,  1.56729596, -0.7174264 ,
#         1.93017811,  3.68306073,  2.05728846, -3.05435561,  2.40805831,
#         0.61003794,  1.74418608,  2.67691184,  2.07683049,  3.76789251,
#         1.86820779,  2.60740158,  2.05311303,  1.74659577,  2.53141425,
#         2.37802007,  2.15677056,  1.86264653,  1.94086651,  2.08692607,
#         2.11242607,  1.78136715,  1.73986792, -0.51229074, -0.30495743,
#        -1.38134021, -5.36103107])

# %% [markdown]
# **Function to bootstrap the differences**: each region needs to be bootstrapped separately. So output would be a matrix with 18 rows and 50 000 bootstraps. And we would get 3 of them for all conditions.

# %%
#input differences between (ketamine - baseline), (placebo - baseline) and (ketamine-placebo) dfs
def calculate_bootstrap(dist_k, dist_p, dist):
    rois = ['OFC1','OFC2','OFC3','OFC4','OFC5','OFC6','OFC7','s32','FP2','25','s24','33','p32','p24ab','p24c','Putamen','NAcc','Caudate']
    k_dict={}
    p_dict={}
    k_p_dict={}
    for roi in rois:
        
        # Bootstrap 50 000 iterations
        # returns bootstrap distribution
        bsr_k_b = bs.bootstrap(np.asarray(dist_k[roi]), stat_func=bs_stats.mean, alpha=0.05, num_iterations=50000, return_distribution=True)
        bsr_p_b = bs.bootstrap(np.asarray(dist_p[roi]), stat_func=bs_stats.mean, alpha=0.05, num_iterations=50000, return_distribution=True)
        bsr = bs.bootstrap(np.asarray(dist[roi]), stat_func=bs_stats.mean, alpha=0.05, num_iterations=50000, return_distribution=True)
        
        # fill dictionaries with ROI: bootstrap list --> 18 x 50.000 
        k_dict[roi] = copy.deepcopy(bsr_k_b)
        p_dict[roi] = copy.deepcopy(bsr_p_b)
        k_p_dict[roi] = copy.deepcopy(bsr)
        

    return k_dict, p_dict, k_p_dict

# %%
[k_dict_s24, p_dict_s24, k_p_dict_s24]= calculate_bootstrap(s24_k_sub_b,s24_p_sub_b,s24_k_p)

# %%
[k_dict_s32, p_dict_s32, k_p_dict_s32]= calculate_bootstrap(s32_k_sub_b,s32_p_sub_b,s32_k_p)

# %% [markdown]
# Prepare dataframes of bootstrap results

# %%
k_dict_s24_df =pd.DataFrame(k_dict_s24)
p_dict_s24_df =pd.DataFrame(p_dict_s24)
k_p_dict_s24_df =pd.DataFrame(k_p_dict_s24)

# %%
k_dict_s32_df=pd.DataFrame(k_dict_s32)
p_dict_s32_df =pd.DataFrame(p_dict_s32)
k_p_dict_s32_df =pd.DataFrame(k_p_dict_s32)

# %% [markdown]
# ### Heatmap for s32 placebo and ketamine for all bootstraps

# %%
# %matplotlib notebook
sns.heatmap(p_dict_s32_df, vmin=-2, vmax=2, center=0)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Bootstrap/bootstrap_heatmap_placebo_s32', dpi=250)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
sns.heatmap(k_dict_s32_df, vmin=-2, vmax=2, center=0)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Bootstrap/bootstrap_heatmap_ketamine_s32', dpi=250)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
sns.heatmap(k_dict_s24_df, vmin=-2, vmax=2, center=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Heatmap for s24 and s32 with all 3 conditions combined

# %% [markdown]
# Calculate mean of bootstrap distribution

# %%
k_dict_s24_mean =np.mean(k_dict_s24_df)
p_dict_s24_mean =np.mean(p_dict_s24_df)
k_p_dict_s24_mean =np.mean(k_p_dict_s24_df)

# %%
k_dict_s32_mean =np.mean(k_dict_s32_df)
p_dict_s32_mean =np.mean(p_dict_s32_df)
k_p_dict_s32_mean =np.mean(k_p_dict_s32_df)

# %%
k_s24= pd.DataFrame(k_dict_s24_mean, columns=['Bootstrap_mean'])
p_s24= pd.DataFrame(p_dict_s24_mean, columns=['Bootstrap_mean'])
k_p_s24= pd.DataFrame(k_p_dict_s24_mean, columns=['Bootstrap_mean'])

# %%
k_s32= pd.DataFrame(k_dict_s32_mean, columns=['Bootstrap_mean'])
p_s32= pd.DataFrame(p_dict_s32_mean, columns=['Bootstrap_mean'])
k_p_s32= pd.DataFrame(k_p_dict_s32_mean, columns=['Bootstrap_mean'])

# %% [markdown]
# Concatenate all conditions

# %%
s24_df = pd.concat([k_s24, p_s24, k_p_s24], axis=1)
s24_df.columns=['Ketamine', 'Placebo', 'Ketamine-Placebo']
s24_df
# Out:
#          Ketamine   Placebo  Ketamine-Placebo
# OFC1     1.229459 -0.879969          2.110149
# OFC2     0.946574 -0.637608          1.583341
# OFC3     0.767511 -0.979137          1.745438
# OFC4     0.799712 -1.170582          1.969284
# OFC5     0.658003 -1.325134          1.985691
# OFC6     0.934697 -1.626086          2.560688
# OFC7     1.065433 -1.400344          2.465647
# s32      0.837827 -0.330780          1.168695
# FP2      0.063418 -0.135899          0.199144
# 25       0.855132 -0.593107          1.449536
# s24      0.842445 -0.233296          1.075740
# 33       0.692206 -0.478703          1.170907
# p32      0.237313  0.052641          0.182303
# p24ab    0.129391 -0.210473          0.340439
# p24c     0.173735 -0.213307          0.387644
# Putamen -2.886534  1.257830         -4.144547
# NAcc    -1.026412  1.143845         -2.169929
# Caudate -0.466685  1.212593         -1.678333

# %%
s24_df = pd.concat([k_s24, p_s24, k_p_s24], axis=1)
s24_df.columns=['Ketamine', 'Placebo', 'Ketamine-Placebo']
s24_df
# Out:
#          Ketamine   Placebo  Ketamine-Placebo
# OFC1     1.229895 -0.880468          2.109204
# OFC2     0.945121 -0.637207          1.583175
# OFC3     0.766597 -0.979559          1.744293
# OFC4     0.799965 -1.170224          1.969949
# OFC5     0.659224 -1.325951          1.984764
# OFC6     0.934614 -1.625508          2.560085
# OFC7     1.066781 -1.400026          2.466133
# s32      0.837393 -0.331551          1.169147
# FP2      0.063149 -0.135627          0.198840
# 25       0.855727 -0.593428          1.448558
# s24      0.842553 -0.233303          1.075606
# 33       0.692289 -0.478628          1.170424
# p32      0.235993  0.053620          0.183304
# p24ab    0.131035 -0.210810          0.341006
# p24c     0.174379 -0.213709          0.388290
# Putamen -2.886871  1.257729         -4.144555
# NAcc    -1.026047  1.142907         -2.169875
# Caudate -0.465621  1.211896         -1.678617

# %%
s32_df = pd.concat([k_s32, p_s32, k_p_s32], axis=1)
s32_df.columns=['Ketamine', 'Placebo', 'Ketamine-Placebo']
s32_df
# Out:
#          Ketamine   Placebo  Ketamine-Placebo
# OFC1     1.256058 -0.513576          1.769321
# OFC2     0.977784 -0.303938          1.281186
# OFC3     0.777326 -0.634937          1.411650
# OFC4     0.767386 -0.825768          1.593278
# OFC5     0.638728 -0.974059          1.612260
# OFC6     0.883417 -1.239298          2.123520
# OFC7     1.018551 -1.029992          2.048301
# s32      0.859439 -0.241844          1.101059
# FP2     -0.026857 -0.421404          0.394463
# 25       0.840560 -0.275449          1.115531
# s24      0.884014 -0.070447          0.954801
# 33       0.674694 -0.350915          1.025343
# p32      0.265451 -0.327973          0.593088
# p24ab    0.163940 -0.532375          0.697372
# p24c     0.205021 -0.597254          0.802618
# Putamen -2.621315  1.433078         -4.053947
# NAcc    -0.740242  1.409388         -2.148851
# Caudate -0.173717  1.550852         -1.725385

# %% [markdown]
# ## Heatmaps

# %% [markdown]
# ### s24

# %%
# %matplotlib notebook
sns.heatmap(s24_df, vmin=-2.8, vmax=2.8, center=0)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Bootstrap/bootstrap_heatmap_s24', dpi=250)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### s32

# %%
# %matplotlib notebook
sns.heatmap(s32_df, vmin=-2.8, vmax=2.8, center=0)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Bootstrap/bootstrap_heatmap_s32', dpi=250)
# Out:
# <img src="data:image/png;base64,..." width="640">
