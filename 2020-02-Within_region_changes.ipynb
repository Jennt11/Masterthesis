# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
import pickle
#from scipy import stats
from scipy import spatial
from scipy.spatial import distance
import scipy.stats as st
import os

# %% [markdown]
# Load dictionaries from the ROIs with all conditions: distances to ROI centroid

# %%
ofc1=np.load('/Users/jenniferthem/Masterthesis_Data/Bootstrap/dist_all_cond_OFC1.npy', allow_pickle=True)
ofc2=np.load('/Users/jenniferthem/Masterthesis_Data/Bootstrap/dist_all_cond_OFC1.npy', allow_pickle=True)
s32=np.load('/Users/jenniferthem/Masterthesis_Data/Bootstrap/dist_all_cond_OFC1.npy', allow_pickle=True)
p24c=np.load('/Users/jenniferthem/Masterthesis_Data/Bootstrap/dist_all_cond_OFC1.npy', allow_pickle=True)

# %% [markdown]
# Extract the conditions

# %%
ofc1_k = pd.DataFrame(ofc1.item().get('Ketamine'), columns=['Distance'])
ofc1_p = pd.DataFrame(ofc1.item().get('Placebo'), columns=['Distance'])
ofc1_b_k = pd.DataFrame(ofc1.item().get('Baseline_k'), columns=['Distance'])
ofc1_b_p = pd.DataFrame(ofc1.item().get('Baseline_p'), columns=['Distance'])

# %%
ofc2_k = pd.DataFrame(ofc2.item().get('Ketamine'), columns=['Distance'])
ofc2_p = pd.DataFrame(ofc2.item().get('Placebo'), columns=['Distance'])
ofc2_b_k = pd.DataFrame(ofc2.item().get('Baseline_k'), columns=['Distance'])
ofc2_b_p = pd.DataFrame(ofc2.item().get('Baseline_p'), columns=['Distance'])

# %%
s32_k = pd.DataFrame(s32.item().get('Ketamine'), columns=['Distance'])
s32_p = pd.DataFrame(s32.item().get('Placebo'), columns=['Distance'])
s32_b_k = pd.DataFrame(s32.item().get('Baseline_k'), columns=['Distance'])
s32_b_p = pd.DataFrame(s32.item().get('Baseline_p'), columns=['Distance'])

# %%
p24c_k = pd.DataFrame(p24c.item().get('Ketamine'), columns=['Distance'])
p24c_p = pd.DataFrame(p24c.item().get('Placebo'), columns=['Distance'])
p24c_b_k = pd.DataFrame(p24c.item().get('Baseline_k'), columns=['Distance'])
p24c_b_p = pd.DataFrame(p24c.item().get('Baseline_p'), columns=['Distance'])

# %% [markdown]
# # OFC1

# %%
# %matplotlib notebook
plot = sns.scatterplot(data=ofc1_k, s=10, legend=False)
plt.title('OFC1 - Ketamine', fontsize=18)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'OFC1 - Ketamine')

# %%
# %matplotlib notebook
plot = sns.scatterplot(data=ofc1_p, s=10, legend=False)
plt.title('OFC1 - Placebo', fontsize=18)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'OFC1 - Placebo')
