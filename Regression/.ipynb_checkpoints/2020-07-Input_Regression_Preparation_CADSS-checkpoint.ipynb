# %% [markdown]
# # Preparation for regression
#
# Creating input and output for regression that predicts dissociation scores (CADSS): only ketamine because for placebo CADSS change is always 0
#
# - for each participant you have one matrix 18 x 25 -> split in 18 x 10 (5 voxel from s24 + 5 voxel from s32) & flatten to be 1 x 180
# - Combine all participants in matrix: 31 x 180
# - standardize the input
#
# (Fc features are already 1h-baseline)

# %%
import numpy as np
import pickle
import pandas as pd
import os
import copy
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# Ketamine subjects: 31
subj_k= np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Ket/New_ketamine_subject_list', allow_pickle=True)

# %%
pd.DataFrame(subj_k, index=None)
# Out:
#        0
# 0   bg52
# 1   bh98
# 2   ce22
# 3   cu52
# 4   dp07
# 5   dp37
# 7   fy78
# 8   gs63
# 9   hw95
# 10  hy97
# 11  ia24
# 12  ia45
# 13  ii39
# 14  il04
# 15  ju09
# 16  ju49
# 17  jw73
# 18  kd21
# 19  kh95
# 20  kw91
# 21  op18
# 22  px00
# 23  qe30
# 24  sr21
# 25  tt42
# 26  uf97
# 27  vg84
# 28  we81
# 29  wo30
# 30  ww25
# 31  yp84

# %%
s24 = np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/LargestChange_voxels/largest_5_voxels_s24', allow_pickle=True)
s32 = np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/LargestChange_voxels/largest_5_voxels_s32', allow_pickle=True)

# %%
s24
# Out:
#              x         y  ROI      ID      Dist      Diff  Diff_k_p
# 5746 -0.443762  0.365012  s24  334197  5.164898  2.576954  6.938511
# 6026 -2.672312  5.033516  s24  344029  9.706677  4.681733  6.639201
# 5744 -2.618876  4.985831  s24  334110  9.654293  4.337812  6.183105
# 5379 -2.882548 -7.995244  s24  324465  3.548302 -0.004987  5.780503
# 5373 -3.003107 -8.374632  s24  324374  3.946344  0.431043  5.659387

# %%
# voxel labels & IDs
labels = np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Labeling/labels_ID', allow_pickle=True)

# %%
labels
# Out:
#        mask_id    label
# 0       205886     OFC1
# 1       205887     OFC1
# 2       205978     OFC1
# 3       206069     OFC1
# 4       206160     OFC1
# ...        ...      ...
# 11878   491073  Caudate
# 11879   491164  Caudate
# 11880   491255  Caudate
# 11881   491346  Caudate
# 11882   491437  Caudate
#
# [11883 rows x 2 columns]

# %%
path_ket = 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Correlation_matrices/ket'
path_placebo = 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Correlation_matrices/placebo'
path_baseline = 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Correlation_matrices/baseline'
# mix of s24&s32 voxels 
rois_list=[s24,s32]

# %%
voxel_list=[]
#voxel_list_all= []
for roi in rois_list:
    voxel_list.append(roi.index.to_list())

# %%
# list of voxels IDs for FC feature extraction
output = []
# function to flatten the list
def remove_nesting(input_list): 
 

    for i in input_list: 
        if type(i) == list: 
            remove_nesting(i) 
        else: 
            output.append(i)

# %%
remove_nesting(voxel_list)

# %%
output
# Out:
# [5746, 6026, 5744, 5379, 5373, 2529, 3635, 2997, 2387, 2417]

# %%
fc_feat=np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Correlation_matrices/ketFC_features-yp84', allow_pickle=True)

# %%
# create feature names
fc_labels=[]
for ind in fc_feat.index:
    for col in output:
        name=str(col)+'_'+ind
        fc_labels.append(copy.deepcopy(name))

# %%
fc_labels
# Out:
# ['5746_25',
#  '6026_25',
#  '5744_25',
#  '5379_25',
#  '5373_25',
#  '2529_25',
#  '3635_25',
#  '2997_25',
#  '2387_25',
#  '2417_25',
#  '5746_33',
#  '6026_33',
#  '5744_33',
#  '5379_33',
#  '5373_33',
#  '2529_33',
#  '3635_33',
#  '2997_33',
#  '2387_33',
#  '2417_33',
#  '5746_Caudate',
#  '6026_Caudate',
#  '5744_Caudate',
#  '5379_Caudate',
#  '5373_Caudate',
#  '2529_Caudate',
#  '3635_Caudate',
#  '2997_Caudate',
#  '2387_Caudate',
#  '2417_Caudate',
#  '5746_FP2',
#  '6026_FP2',
#  '5744_FP2',
#  '5379_FP2',
#  '5373_FP2',
#  '2529_FP2',
#  '3635_FP2',
#  '2997_FP2',
#  '2387_FP2',
#  '2417_FP2',
#  '5746_NAcc',
#  '6026_NAcc',
#  '5744_NAcc',
#  '5379_NAcc',
#  '5373_NAcc',
#  '2529_NAcc',
#  '3635_NAcc',
#  '2997_NAcc',
#  '2387_NAcc',
#  '2417_NAcc',
#  '5746_OFC1',
#  '6026_OFC1',
#  '5744_OFC1',
#  '5379_OFC1',
#  '5373_OFC1',
#  '2529_OFC1',
#  '3635_OFC1',
#  '2997_OFC1',
#  '2387_OFC1',
#  '2417_OFC1',
#  '5746_OFC2',
#  '6026_OFC2',
#  '5744_OFC2',
#  '5379_OFC2',
#  '5373_OFC2',
#  '2529_OFC2',
#  '3635_OFC2',
#  '2997_OFC2',
#  '2387_OFC2',
#  '2417_OFC2',
#  '5746_OFC3',
#  '6026_OFC3',
#  '5744_OFC3',
#  '5379_OFC3',
#  '5373_OFC3',
#  '2529_OFC3',
#  '3635_OFC3',
#  '2997_OFC3',
#  '2387_OFC3',
#  '2417_OFC3',
#  '5746_OFC4',
#  '6026_OFC4',
#  '5744_OFC4',
#  '5379_OFC4',
#  '5373_OFC4',
#  '2529_OFC4',
#  '3635_OFC4',
#  '2997_OFC4',
#  '2387_OFC4',
#  '2417_OFC4',
#  '5746_OFC5',
#  '6026_OFC5',
#  '5744_OFC5',
#  '5379_OFC5',
#  '5373_OFC5',
#  '2529_OFC5',
#  '3635_OFC5',
#  '2997_OFC5',
#  '2387_OFC5',
#  '2417_OFC5',
#  '5746_OFC6',
#  '6026_OFC6',
#  '5744_OFC6',
#  '5379_OFC6',
#  '5373_OFC6',
#  '2529_OFC6',
#  '3635_OFC6',
#  '2997_OFC6',
#  '2387_OFC6',
#  '2417_OFC6',
#  '5746_OFC7',
#  '6026_OFC7',
#  '5744_OFC7',
#  '5379_OFC7',
#  '5373_OFC7',
#  '2529_OFC7',
#  '3635_OFC7',
#  '2997_OFC7',
#  '2387_OFC7',
#  '2417_OFC7',
#  '5746_Putamen',
#  '6026_Putamen',
#  '5744_Putamen',
#  '5379_Putamen',
#  '5373_Putamen',
#  '2529_Putamen',
#  '3635_Putamen',
#  '2997_Putamen',
#  '2387_Putamen',
#  '2417_Putamen',
#  '5746_p24ab',
#  '6026_p24ab',
#  '5744_p24ab',
#  '5379_p24ab',
#  '5373_p24ab',
#  '2529_p24ab',
#  '3635_p24ab',
#  '2997_p24ab',
#  '2387_p24ab',
#  '2417_p24ab',
#  '5746_p24c',
#  '6026_p24c',
#  '5744_p24c',
#  '5379_p24c',
#  '5373_p24c',
#  '2529_p24c',
#  '3635_p24c',
#  '2997_p24c',
#  '2387_p24c',
#  '2417_p24c',
#  '5746_p32',
#  '6026_p32',
#  '5744_p32',
#  '5379_p32',
#  '5373_p32',
#  '2529_p32',
#  '3635_p32',
#  '2997_p32',
#  '2387_p32',
#  '2417_p32',
#  '5746_s24',
#  '6026_s24',
#  '5744_s24',
#  '5379_s24',
#  '5373_s24',
#  '2529_s24',
#  '3635_s24',
#  '2997_s24',
#  '2387_s24',
#  '2417_s24',
#  '5746_s32',
#  '6026_s32',
#  '5744_s32',
#  '5379_s32',
#  '5373_s32',
#  '2529_s32',
#  '3635_s32',
#  '2997_s32',
#  '2387_s32',
#  '2417_s32']

# %%
fc_feat[output]
# Out:
#              5746      6026      5744      5379      5373      2529      3635  \
# label
# 25       0.003509 -0.053212 -0.040338 -0.017236  0.006721 -0.010726 -0.085928
# 33       0.014634 -0.016518  0.019011 -0.004295  0.037875 -0.000351 -0.018772
# Caudate  0.037510  0.033044  0.043492 -0.017644  0.000063 -0.013106  0.011546
# FP2     -0.050635  0.019457 -0.089321 -0.009195 -0.026744  0.052118 -0.029972
# NAcc     0.015031  0.026629 -0.003775 -0.019474  0.011706 -0.001287  0.019484
# OFC1    -0.026356 -0.017358 -0.002951  0.056054  0.009495  0.001339 -0.004071
# OFC2    -0.009870 -0.069696 -0.052698 -0.001035  0.005359  0.005332 -0.046635
# OFC3    -0.018300 -0.004925 -0.014215  0.002427  0.000519 -0.017455 -0.000857
# OFC4    -0.051269  0.011568 -0.042262 -0.005736 -0.043312 -0.032217  0.047081
# OFC5    -0.027833 -0.046167 -0.073854 -0.018082 -0.000817  0.000035  0.034579
# OFC6    -0.041162 -0.019304 -0.047615 -0.008106 -0.035978 -0.028824  0.006448
# OFC7    -0.046123  0.018090 -0.080702 -0.005129 -0.047715  0.028981  0.010176
# Putamen -0.004053  0.060503  0.020096 -0.008625  0.000968 -0.018213 -0.013959
# p24ab   -0.072174  0.034493 -0.013959 -0.014560  0.010450  0.000126 -0.013384
# p24c    -0.033100  0.048819 -0.058817 -0.003464 -0.022202  0.063132 -0.042999
# p32     -0.034892  0.022804 -0.070438 -0.021147 -0.022697  0.059101 -0.025417
# s24      0.000000  0.002649 -0.025165 -0.019744  0.009209  0.005649 -0.041722
# s32     -0.028866  0.042397 -0.035304 -0.035782  0.002913 -0.012629 -0.043129
#
#              2997      2387      2417
# label
# 25      -0.095903  0.066681 -0.000848
# 33      -0.039443  0.026857 -0.002179
# Caudate -0.020265  0.053435  0.028905
# FP2      0.047131 -0.012522 -0.016687
# NAcc    -0.011445  0.018221 -0.038589
# OFC1     0.030382  0.068477  0.031217
# OFC2    -0.024912  0.052561  0.014382
# OFC3     0.002378 -0.000011 -0.008208
# OFC4     0.021559 -0.032983 -0.019252
# OFC5    -0.011638  0.013751  0.032707
# OFC6     0.048428 -0.004946  0.019142
# OFC7     0.071063 -0.049677 -0.026033
# Putamen  0.036358  0.010221  0.000822
# p24ab    0.006884 -0.029829 -0.044744
# p24c     0.027116 -0.011627 -0.011257
# p32      0.038792 -0.013703 -0.041555
# s24     -0.011939 -0.006664 -0.022846
# s32      0.031798 -0.012914 -0.018863

# %%
# create features
def create_X(subj_list):
    
    # choose path according to saving directory dependend on treatment
    path = 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Correlation_matrices/ketFC_features-'
    
    #print(path)
    i=0
    
    for subj in subj_list:
        
        subj_name= str(subj)
        subj_path = path+subj_name
        # load features
        fc_feature = np.load(subj_path, allow_pickle=True)
        
        # extracting the columns for each input
        # X_1:
        X_feat= fc_feature[output].to_numpy()
        
        # flatten matrix from each particpant & stacking them up for all participants
        if i==0:
            # first round 
            X_1 = copy.deepcopy(X_feat.flatten())
        else:
            # all other rounds
            # vstack produces copy
            X_1 = np.vstack((X_1, X_feat.flatten()))

            
        i+=1 
    
    X_saving= pd.DataFrame(X_1)
    X_saving.columns=[fc_labels]
    X_saving.to_csv('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/X_CADSS.csv')
    np.save('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/X_CADSS.npy', X_1)
        
    return X_1

# %%
create_X(subj_k)
# Out:
# array([[ 0.02065953, -0.00560762,  0.04118455, ...,  0.05455154,
#         -0.0123629 ,  0.03191745],
#        [ 0.01806276,  0.01072323,  0.04145866, ..., -0.01288898,
#         -0.01648653,  0.03581572],
#        [ 0.01831241,  0.00035668, -0.02099165, ...,  0.01697421,
#          0.00162351,  0.00554154],
#        ...,
#        [ 0.01318505,  0.06973279,  0.01041893, ..., -0.03749344,
#          0.00311279, -0.04022765],
#        [ 0.02960099, -0.00591524,  0.01017704, ...,  0.00018886,
#         -0.03750974, -0.03645243],
#        [ 0.00350948, -0.05321166, -0.04033768, ...,  0.03179767,
#         -0.0129138 , -0.01886333]])

# %%
pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/X_CADSS.csv')
# Out:
#     Unnamed: 0   5746_25   6026_25   5744_25   5379_25   5373_25   2529_25  \
# 0            0  0.020660 -0.005608  0.041185 -0.030193 -0.058457 -0.036553
# 1            1  0.018063  0.010723  0.041459 -0.029035 -0.045968 -0.004066
# 2            2  0.018312  0.000357 -0.020992 -0.039164  0.013780 -0.051414
# 3            3  0.011108 -0.028160  0.078615  0.081585 -0.015826  0.080635
# 4            4 -0.023551  0.039279  0.040005  0.008475 -0.036829 -0.169826
# 5            5 -0.005198 -0.037815 -0.056692 -0.008820  0.024371 -0.072914
# 6            6 -0.067479 -0.059374  0.011223 -0.061973 -0.046137  0.113473
# 7            7 -0.035121 -0.035431  0.019192  0.071133  0.000851 -0.011997
# 17  0.053368  0.070894 -0.033771 -0.000628 -0.040075 -0.010542
# 18 -0.000136  0.015501  0.001282  0.077618 -0.005049  0.028408
# 19  0.080235  0.077666  0.120236  0.118945  0.023543  0.059682
# 20 -0.040396 -0.012022  0.025577  0.000639  0.031611 -0.021340
# 21  0.015621 -0.079806 -0.015084  0.029373  0.042562  0.006880
# 22  0.017453 -0.064176 -0.012053 -0.034096 -0.057092 -0.047025
# 23 -0.029638 -0.026434  0.033781  0.035174 -0.011874  0.005312
# 24 -0.036424  0.029216  0.007805  0.047429  0.005840 -0.000468
# 25  0.141914  0.127524  0.051459  0.063982 -0.011034  0.059291
# 26 -0.039563 -0.027265 -0.087108  0.040392 -0.049298 -0.041318
# 27 -0.012334 -0.033160  0.027101  0.020737  0.036249 -0.002075
# 28 -0.012443  0.103078 -0.062002 -0.037493  0.003113 -0.040228
# 29  0.031213 -0.032467 -0.062018  0.000189 -0.037510 -0.036452
# 30  0.002913 -0.012629 -0.043129  0.031798 -0.012914 -0.018863
#
# [31 rows x 181 columns]

# %%
scaler = StandardScaler()
#print(scaler.fit(data))
StandardScaler()

# %%
# standardize the features
X_1_k_st=scaler.fit_transform(X_1_k)

# %%
x1_k_st_df=pd.DataFrame(X_1_k_st)
# connect with features names
x1_k_st_df.columns=[fc_labels_X1]
x1_k_st_df.to_pickle('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Correlation_matrices/Input_ket_s24_s32_standardized')
x1_k_st_df

# %% [markdown]
# # CADSS score

# %%
ket_csv=pd.read_csv('C:/Users/canlab/Desktop/Masterthesis_python/data/Ket_overview.csv')

# %%
ket_csv
# Out:
#    ID Nr. Behandlungsart  CADSS
# 0    ap75        Placebo      0
# 1    bg52          Verum     35
# 2    bh27        Placebo      0
# 3    bh98          Verum     31
# 4    bu45        Placebo      0
# ..    ...            ...    ...
# 86   xc25          Verum      0
# 87   xp38        Placebo      0
# 88   yh25          Verum     15
# 89   yp84          Verum     10
# 90   zr76          Verum      2
#
# [91 rows x 3 columns]

# %%
split_csv = ket_csv.groupby('Behandlungsart')
# get the median correlation of the ROIs
k_csv_df = split_csv.get_group('Verum')

# %%
k_csv_df=k_csv_df.set_index('ID Nr.')

# %%
k_csv_df.loc[subj_k]
# Out:
#        Behandlungsart  CADSS
# ID Nr.
# bg52            Verum     35
# bh98            Verum     31
# ce22            Verum      1
# cu52            Verum     15
# dp07            Verum      8
# dp37            Verum     14
# fy78            Verum     20
# gs63            Verum      8
# hw95            Verum      0
# hy97            Verum      9
# ia24            Verum     23
# ia45            Verum      4
# ii39            Verum     14
# il04            Verum     14
# ju09            Verum     14
# ju49            Verum     15
# jw73            Verum     13
# kd21            Verum      3
# kh95            Verum      0
# kw91            Verum     16
# op18            Verum      0
# px00            Verum      1
# qe30            Verum      2
# sr21            Verum      1
# tt42            Verum      6
# uf97            Verum     10
# vg84            Verum      3
# we81            Verum      5
# wo30            Verum      4
# ww25            Verum      0
# yp84            Verum     10

# %%
k_csv_df.to_pickle('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/CADSS_ket')
