# %%
# %matplotlib inline
import numpy as np
import pandas as pd
#from ggplot import *
import matplotlib.pyplot as plt
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap
from plotnine import *
import seaborn as sns

# %%
# selfmade for 18 colors - 18 ROIs
colors18 = ['#ED1D0C','#808000', '#FA8072', '#7DDCAC', '#097E02', '#7988DF', '#38E1F5', '#1C0BEA', '#39374D', '#EC7BD9', '#560449', '#D192B8', '#F57A64', '#921701', '#A877EE', '#CCCC00', '#BD11A1', '#89AB94']

# %%
b_k=np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Ket/UMAP_ROI_Baseline_ketamine', allow_pickle=True)
k=np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Ket/UMAP_ROI_Ketamine', allow_pickle=True)
p=np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Placebo/UMAP_ROI_Baseline_placebo', allow_pickle=True)
b_p=np.load('C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Placebo/UMAP_ROI_Placebo', allow_pickle=True)

# %%
def plotting_rois(UMAP_roi_df, name,path):
    # %matplotlib notebook
    sns.set_context("paper")
    sns.set_style("darkgrid")
    #sns.set(font_scale = 1.5)
    plt.figure(figsize=(10, 8))
    keys = ['OFC1', 'OFC2', 'OFC3', 'OFC4', 'OFC5', 'OFC6', 'OFC7', 'FP2', '25', 's24', 's32', '33', 'p24ab', 'p24c', 'p32',  'Putamen', 'NAcc', 'Caudate']
    sp = sns.scatterplot(x="x", y="y", hue='ROI', hue_order=keys, data=UMAP_roi_df, palette = colors18, legend = False, s=35, alpha=0.5)
    #sp = sns.scatterplot(x="x", y="y", hue='ROI', hue_order=keys, data=UMAP_roi_df, palette = colors18, legend = 'full', s=35, alpha=0.5)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., markerscale=2)
    plt.title(name, fontsize=26)
    plt.gca().invert_xaxis()
    #plt.setp(sp.get_legend().get_texts(), fontsize='24') # for legend text
    #plt.setp(sp.get_legend().get_title(), fontsize='32') # for the legend title
    plt.setp(sp,xticks=[-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10], yticks=[-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10])
    plt.xlabel('x', fontsize=24)
    plt.ylabel('y', fontsize=24)
    plt.tick_params(labelsize=22)
    sns.despine(top=True,offset=5)
    plt.tight_layout()
    plt.savefig(path, dpi=250)

# %%
plotting_rois(b_k, 'Baseline (Ketamine)', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Baseline_Ket_new_legend')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">

# %%
plotting_rois(b_k, 'Baseline (Ketamine)', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Baseline_Ket_new')

# %%
plotting_rois(k, 'Ketamine', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Ket_new')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">
# No handles with labels found to put in legend.

# %%
plotting_rois(b_p, 'Baseline (Placebo)', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Baseline_placebo_new')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">
# No handles with labels found to put in legend.

# %%
plotting_rois(p, 'Placebo','C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Placebo_new')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">
# No handles with labels found to put in legend.

# %%
#%matplotlib inline
plotting_rois(b_k, 'Baseline (Ketamine)', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Baseline_Ket')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">

# %%
plotting_rois(k, 'Ketamine','C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Ket')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">

# %%
p
# Out:
#               x         y      ROI
# 0      2.550392 -2.875287     OFC1
# 1      2.285942 -4.092873     OFC1
# 2      2.986234 -3.069937     OFC1
# 3      3.101693 -3.235654     OFC1
# 4      3.032506 -3.365405     OFC1
# ...         ...       ...      ...
# 11878 -0.619342  1.684050  Caudate
# 11879 -0.624093  1.701689  Caudate
# 11880 -0.661921  1.710923  Caudate
# 11881 -0.667506  1.682475  Caudate
# 11882 -0.694166  1.691140  Caudate
#
# [11883 rows x 3 columns]

# %%
plotting_rois(p, 'Placebo','C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Placebo')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">

# %%
plotting_rois(b_p, 'Baseline (Placebo)', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Baseline_Placebo')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">

# %%
plotting_rois(b_p, 'Baseline (Placebo)', 'C:/Users/canlab/Desktop/Masterthesis_python/ReDoneAnalysis20200420/Plots/Baseline_Placebo_inverted')
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">

# %%
b_p
# Out:
#               x         y      ROI
# 0     -2.739387 -3.736372     OFC1
# 1     -2.474142 -3.229756     OFC1
# 2     -3.009511 -3.525998     OFC1
# 3     -3.031270 -3.398739     OFC1
# 4     -2.920102 -4.031644     OFC1
# ...         ...       ...      ...
# 11878  0.621853  2.811207  Caudate
# 11879  0.642768  2.803928  Caudate
# 11880  0.593797  2.761256  Caudate
# 11881  0.626058  2.782596  Caudate
# 11882  0.591184  2.727303  Caudate
#
# [11883 rows x 3 columns]

# %%
p = ggplot(aes(x='x', y='y',color='ROI'), b_k)
p + geom_point(size=0.5,alpha = 0.3)
# Out:
# <ggplot: (-9223371896120983116)>

# %%
# saving image
p.save("images/beautiful_plot_from_notebook.png")
