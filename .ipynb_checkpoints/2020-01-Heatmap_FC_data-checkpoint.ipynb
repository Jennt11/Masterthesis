# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot as plt

# %%
baseline_mat = np.load('/Users/jenniferthem/Masterthesis_Data/corr_dist_df_baseline.npy')
#ket_mat = np.load('/Users/jenniferthem/Masterthesis_Data/Ketamine_corr_dist.npy')
#placebo_mat = np.load('/Users/jenniferthem/Masterthesis_Data/Placebo_corr_dist.npy')

# %%
ket_mat = np.load('/Users/jenniferthem/Masterthesis_Data/Ketamine_corr_dist.npy')
placebo_mat = np.load('/Users/jenniferthem/Masterthesis_Data/Placebo_corr_dist.npy')

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(baseline_mat)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Heatmap_baseline', dpi=250)

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(ket_mat)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Heatmap_ketamine', dpi=250)

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(placebo_mat)
plt.savefig('/Users/jenniferthem/Masterthesis_Data/Heatmap_placebo', dpi=250)
